# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2

# %%
image=cv2.imread("/content/test_4.jpg",cv2.COLOR_RGB2BGR)
plt.imshow(image)

# %%
image.shape
# Out:
# (6936, 9248, 3)

# %%
image_R=image[:,:,0]
image_G=image[:,:,1]
image_B=image[:,:,2]

# %%
image_R.shape, image_G.shape, image_B.shape
# Out:
# ((6936, 9248), (6936, 9248), (6936, 9248))

# %%
plt.imshow(image_R)

# %%
image_R_f=image_R.reshape(-1,6936*9248)
image_G_f=image_G.reshape(-1,6936*9248)
image_B_f=image_B.reshape(-1,6936*9248)

# %%
image_R_f.shape
# Out:
# (1, 64144128)

# %%
image_RGB=np.column_stack((image_R_f,image_G_f,image_B_f))
image_RGB.shape
# Out:
# (1, 192432384)

# %%
image_RGB
# Out:
# array([[ 54,  52,  48, ..., 146, 146, 146]], dtype=uint8)
